# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action='ignore',category=np.VisibleDeprecationWarning)

# %% [markdown]
# # Practice with tables #

# %% [markdown]
# ## Skyscraper data analysis ##

# %%
# From the CORGIS Dataset Project
# By Austin Cory Bart acbart@vt.edu
# Version 2.0.0, created 3/22/2016
# https://corgis-edu.github.io/corgis/csv/skyscrapers/

sky = Table.read_table('skyscrapers.csv')
sky = (sky.with_column('age', 2025 - sky.column('completed'))
          .drop('completed'))
sky.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>material</th> <th>city</th> <th>height</th> <th>age</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>One World Trade Center</td> <td>mixed/composite</td> <td>New York City</td> <td>541.3 </td> <td>11  </td>
#         </tr>
#         <tr>
#             <td>Willis Tower          </td> <td>steel          </td> <td>Chicago      </td> <td>442.14</td> <td>51  </td>
#         </tr>
#         <tr>
#             <td>432 Park Avenue       </td> <td>concrete       </td> <td>New York City</td> <td>425.5 </td> <td>10  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1778 rows omitted)</p>

# %%
# 0. Which city has the highest average height? The lowest?

# %%
# 1. For each city, how tall is the tallest building for each material? 
# Make a pivot table to summarize this data.

# %%
# 2. Choose two cities, one older and one newer (e.g. Boston versus Phoenix).
# Make a scatter plot of building height against age for both of the cities.

# %%
# 3. For each city, what’s the height difference between the tallest 
#    steel building and the tallest concrete building?

# %% [markdown]
# Don't read ahead until you try the challenge questions yourself first!

# %%
sky.select('material', 'city', 'height').group(['city', 'material'], collect=max)

# %%
sky_p = sky.pivot('material', 'city', values='height', collect=max)
sky_p.show()

# %%
sky_p = sky_p.with_column(
    'difference', 
    abs(sky_p.column('steel') - sky_p.column('concrete'))
)
sky_p

# %%
sky_p.sort('difference', True)

# %%
# 4. Generate a table of the names of the oldest buildings for each 
#    material for each city:

# Hint: You can use sort to find the name of the oldest building in the dataset
sky.sort('age', descending=True).column('name').item(0)

# %% [markdown]
# (No peeking! A solution appears below.)

# %%
def first(s):
    "Return the first element in an array."
    return s.item(0)

(sky
 .sort('age', descending=True)
 .pivot('material', 'city', 'name', first)
)#.where('city', 'San Francisco')
